# %% [markdown]
# Team members Names and PIDs:
#
# Paula Campaña Donoso - 730723162
#
# Brad Weyand - 730318989
#
# Siwei Han - 730723179
#
# Thomas Kung - 730620459

# %% [markdown]
# ### * Please change the path name for the .csv file to work, thank you!

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, /kaggle/input/mushrooms/mushroom_csv.csvCSV file I/O (e.g. pd.read_csv)
import os

path = '/content/mushroom_csv.csv'
df = pd.read_csv(path)
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-40cfa6ce15dc> in <cell line: 6>()
#       4
#       5 path = '/content/mushroom_csv.csv'
# ----> 6 df = pd.read_csv(path)
#       7 df.head()
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
df.tail()
# Out:
#      cap-shape cap-surface cap-color bruises%3F odor gill-attachment  \
# 8119         k           s         n          f    n               a
# 8120         x           s         n          f    n               a
# 8121         f           s         n          f    n               a
# 8122         k           y         n          f    y               f
# 8123         x           s         n          f    n               a
#
#      gill-spacing gill-size gill-color stalk-shape  ...  \
# 8119            c         b          y           e  ...
# 8120            c         b          y           e  ...
# 8121            c         b          n           e  ...
# 8122            c         n          b           t  ...
# 8123            c         b          y           e  ...
#
#      stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 8119                      o                      o         p          o
# ...

# %%
df.shape
# Out:
# (8124, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   cap-shape                 8124 non-null   object
#  1   cap-surface               8124 non-null   object
#  2   cap-color                 8124 non-null   object
#  3   bruises%3F                8124 non-null   object
#  4   odor                      8124 non-null   object
#  5   gill-attachment           8124 non-null   object
#  6   gill-spacing              8124 non-null   object
#  7   gill-size                 8124 non-null   object
#  8   gill-color                8124 non-null   object
#  9   stalk-shape               8124 non-null   object
#  10  stalk-root                5644 non-null   object
#  11  stalk-surface-above-ring  8124 non-null   object
#  12  stalk-surface-below-ring  8124 non-null   object
# ...

# %%
df.describe()
# Out:
#        cap-shape cap-surface cap-color bruises%3F  odor gill-attachment  \
# count       8124        8124      8124       8124  8124            8124
# unique         6           4        10          2     9               2
# top            x           y         n          f     n               f
# freq        3656        3244      2284       4748  3528            7914
#
#        gill-spacing gill-size gill-color stalk-shape  ...  \
# count          8124      8124       8124        8124  ...
# unique            2         2         12           2  ...
# top               c         b          b           t  ...
# freq           6812      5612       1728        4608  ...
#
#        stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# count                    8124                   8124      8124       8124
# unique                      9                      9         1          4
# top                         w                      w         p          w
# ...

# %%
#One-hot-encoding
# Display the original dataset
df_1 = pd.read_csv(path)
print("Original Dataset:")
print(df_1)

# One-hot encode categorical columns
df_1 = pd.get_dummies(df_1, columns=['cap-shape',
                                 'cap-surface',
                                 'cap-color',
                                 'bruises%3F',
                                 'odor',
                                 'gill-attachment',
                                 'gill-spacing',
                                 'gill-size',
                                 'gill-color',
                                 'stalk-shape',
                                 'stalk-root',
                                 'stalk-surface-above-ring',
                                 'stalk-surface-below-ring',
                                 'stalk-color-above-ring',
                                 'stalk-color-below-ring',
                                 'veil-type',
                                 'veil-color',
                                 'ring-number',
                                 'ring-type',
                                 'spore-print-color',
                                 'population',
                                 'habitat',
                                 'class'])

# Display the dataset after conversion
print("\nDataset after Conversion:")
print(df_1)
# Out:
# Original Dataset:
#      cap-shape cap-surface cap-color bruises%3F odor gill-attachment  \
# 0            x           s         n          t    p               f
# 1            x           s         y          t    a               f
# 2            b           s         w          t    l               f
# 3            x           y         w          t    p               f
# 4            x           s         g          f    n               f
# ...        ...         ...       ...        ...  ...             ...
# 8119         k           s         n          f    n               a
# 8120         x           s         n          f    n               a
# 8121         f           s         n          f    n               a
# 8122         k           y         n          f    y               f
# 8123         x           s         n          f    n               a
#
#      gill-spacing gill-size gill-color stalk-shape  ...  \
# 0               c         n          k           e  ...
# ...

# %%
#Label encoding(Dummy numbers)
# Display the original dataset
df_2 = pd.read_csv(path)

print("Original Dataset:")
print(df_2)

# Iterate through each column in the DataFrame
for column in df_2.columns:
    # Check if the data type of the column is 'object' (string)
    if df_2[column].dtype == 'object':
        # Convert string values to integers
        df_2[column] = pd.Categorical(df_2[column])
        df_2[column] = df_2[column].cat.codes

# Display the dataset after conversion
print("\nDataset after Conversion:")
print(df_2)
# Out:
# Original Dataset:
#      cap-shape cap-surface cap-color bruises%3F odor gill-attachment  \
# 0            x           s         n          t    p               f
# 1            x           s         y          t    a               f
# 2            b           s         w          t    l               f
# 3            x           y         w          t    p               f
# 4            x           s         g          f    n               f
# ...        ...         ...       ...        ...  ...             ...
# 8119         k           s         n          f    n               a
# 8120         x           s         n          f    n               a
# 8121         f           s         n          f    n               a
# 8122         k           y         n          f    y               f
# 8123         x           s         n          f    n               a
#
#      gill-spacing gill-size gill-color stalk-shape  ...  \
# 0               c         n          k           e  ...
# ...

# %%
# visualization
import seaborn as sns
import matplotlib.pyplot as plt

img_path = 'imgs'
if not os.path.exists(img_path):
    os.makedirs(img_path)

# show every graph in one page
i=1
plt.figure(figsize=(30, 48))
for column in df.columns[:-1]:
    plt.subplot(8,3,i)
    # plt.figure(figsize=(10, 6))
    sns.countplot(y=column, hue="class", data=df, palette=['crimson', 'mediumspringgreen'])
    plt.xlabel("count",fontsize=20)
    plt.ylabel(column,fontsize=20)
    plt.legend(fontsize=20)
    plt.tick_params(axis='both', labelsize=16)
    plt.title(f'Distribution of {column} by edibility',fontsize=20)
    i+=1
name=img_path+"/all"
plt.subplots_adjust(left=0.05, right=0.95, top=0.95, bottom=0.05, hspace=0.6, wspace=0.2)
plt.savefig(name)
plt.show()
plt.close()

# save each graph in different file
# for column in df.columns[:-1]:
#     plt.figure(figsize=(10, 6))
#     sns.countplot(y=column, hue="class", data=df, palette=['crimson', 'mediumspringgreen'])
#     plt.xlabel("count",fontsize=20)
#     plt.ylabel(column,fontsize=20)
#     plt.title(f'Distribution of {column} by edibility',fontsize=20)
#     plt.legend(fontsize=20)
#     plt.tick_params(axis='both', labelsize=16)
#     name=img_path+"/"+column
#     plt.savefig(name)
#     plt.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e2797386bf01> in <cell line: 6>()
#       4
#       5 img_path = 'imgs'
# ----> 6 if not os.path.exists(img_path):
#       7     os.makedirs(img_path)
#       8
#
# NameError: name 'os' is not defined
